# %%
from openai import OpenAI
import json
import random
import re
from goat_planner.utils.bt_validator import validate_behavior_tree
from prompt_data import action_list, object_list
random.seed(42)

# %%
def generate_query_prompt(object_context, action_context, last_queries):
    base_prompt = """
You are simulating a human planning a task for a robot. The robot is equipped with sensors, manipulators, and mobility capabilities, and can perform tasks based on the objects in its environment and the actions available. It can also plan multi-step tasks or respond to impossible queries by indicating they cannot be completed.

Object Context: 
{object_context}

Actions Context:
{action_context}

Generate a human-like query for the robot based on the given context and actions. Ensure that the queries vary in complexity:
- Some queries should be straightforward (e.g., single-step tasks).
- Some queries should be multi-step or involve reasoning (e.g., combining multiple actions or making decisions based on object attributes).
- Occasionally, generate queries that are impossible to execute (e.g., due to missing objects, incompatible actions, or physical limitations).

Here is the list of old queries that you created:
{last_queries}

Be creative and simulate realistic scenarios. The queries should be natural and diverse, for example:
- Go find something to eat that's not too salty.
- Close the hot water valve in the kitchen.
- Go make dinner and set the table.
- Help the firefighter put out the fire by spraying water on it.

Generate only a single query.
"""

    full_prompt = base_prompt.format(
        object_context=object_context,
        action_context=action_context,
        last_queries="\n".join(last_queries)
    )
    return full_prompt, object_context


last_queries = ["no last query"]

query, reduced_object_list = generate_query_prompt(object_list, action_list, last_queries)

# %%
def generate_bt_prompt(object_context, action_context, query):
    base_prompt = """
You are a robot that generate Behavior Tree with actions and context in a ROS2-compatible environment. The robot is equipped with sensors, manipulators, and mobility capabilities, and can execute tasks using behavior trees.

Object Context: 
{object_context}

Actions Context:
{action_context}

Generate a Behavior Tree XML structure based on the given context and actions. The tree should:
- Include nodes for sequence (`Sequence`), fallback (`Fallback`), and actions based on the actions dictionary.
- Use realistic action nodes with specified parameters for the given scenario.
- Allow for graceful recovery from failures using fallback nodes.
- If the query is not possible to execute, you must explain why and return an empty Behavior Tree XML.


Detail what you are going to do and then generate a Behavior Tree XML for it. Exemple for the query: "Go find something to eat that's not too salty."

You must respect the following format:

[Explanation]
Good, I will check in my database which objects match the query. If there is a good match, I will navigate to it and pick it up. Otherwise, I will try to find a kitchen, open the fridge, and try to find something to eat that's not too salty. Then I'll bring it back to the table.

[Behavior Tree]
<root main_tree_to_execute="FindAndRetrieveFoodSequence">
    <BehaviorTree ID="FindAndRetrieveFoodSequence">
        <Sequence name="FindAndRetrieveFood">
            <Retry num_attempts="3">
                <Locate object="food not too salty" 
                        position_x="{{food_position_x}}" 
                        position_y="{{food_position_y}}" 
                        position_z="{{food_position_z}}" />
            </Retry>
            <Fallback name="HandleFoodSearchFallback">
                <Sequence name="DirectFoodRetrieval">
                    <Retry num_attempts="2">
                        <Navigate x="{{food_position_x}}" y="{{food_position_y}}" />
                    </Retry>
                    <Retry num_attempts="2">
                        <Pick object="food not too salty" 
                              grip_strength="medium" 
                              precision="high" />
                    </Retry>
                </Sequence>
                <Sequence name="KitchenSearchAndRetrieve">
                    <Retry num_attempts="2">
                        <Navigate x="{{kitchen_position_x}}" y="{{kitchen_position_y}}" />
                    </Retry>
                    <Retry num_attempts="3">
                        <Locate object="fridge" 
                                position_x="{{fridge_position_x}}" 
                                position_y="{{fridge_position_y}}" 
                                position_z="{{fridge_position_z}}" />
                    </Retry>
                    <Retry num_attempts="2">
                        <Navigate x="{{fridge_position_x}}" y="{{fridge_position_y}}" />
                    </Retry>
                    <Retry num_attempts="3">
                        <Locate object="food not too salty" 
                                position_x="{{food_position_x}}" 
                                position_y="{{food_position_y}}" 
                                position_z="{{food_position_z}}" />
                    </Retry>
                    <Retry num_attempts="2">
                        <Pick object="food not too salty" 
                              grip_strength="medium" 
                              precision="high" />
                    </Retry>
                </Sequence>
            </Fallback>
            <Retry num_attempts="2">
                <Navigate x="{{table_position_x}}" y="{{table_position_y}}" />
            </Retry>
            <Retry num_attempts="2">
                <Place object="food not too salty" 
                       surface="table" 
                       orientation="upright" 
                       alignment="center" />
            </Retry>
        </Sequence>
    </BehaviorTree>
</root>


The answer must contains only those two parts (Explanation and Behavior Tree XML). 
Query: {query}
""" # Generate samples for object context and actions 
  
    full_prompt = base_prompt.format(
      object_context=object_context,
      action_context=action_context,
      query=query
      )
    return full_prompt


query = "Go find something to eat that's not too salty."
bt_prompt = generate_bt_prompt(reduced_object_list, action_list, query)

# %%
def generate_query(query_prompt):
    client = OpenAI()

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": query_prompt}],
        max_tokens=1000,
        temperature=0.7
    )
    return response.choices[0].message.content.strip()

# %%
def extract_explanation_and_bt(bt_prompt):
    explanation_match = re.search(r"\[Explanation\]\n(.*?)\n\[Behavior Tree\]", bt_prompt, re.S)
    bt_match = re.search(r"\[Behavior Tree\]\n(.*)", bt_prompt, re.S)  # Adjusted to capture everything after [Behavior Tree]
    
    explanation = explanation_match.group(1).strip() if explanation_match else ""
    bt = bt_match.group(1).strip() if bt_match else ""
    return explanation, bt

explanation, bt = extract_explanation_and_bt(bt_prompt)
# print(explanation)
# print(bt)

# %%
from goat_planner.utils.json_xml_convertor import xml_to_json


def generate_dataset(object_context, action_list, dataset_size=20):
    dataset = []
    last_queries = []  # To store the last 10 queries
    
    for _ in range(dataset_size):
        # Randomly select captions and actions
        reduced_object_list = random.sample(object_context, random.randint(3, 12))
        
        # Generate query
        query_prompt, _ = generate_query_prompt(reduced_object_list, action_list, last_queries)
        query = generate_query(query_prompt)
        bt_prompt = generate_bt_prompt(reduced_object_list, action_list, query)
        answer = generate_query(bt_prompt)
        explanation, bt_xml = extract_explanation_and_bt(answer)


        action_node = ["Sequence", "Fallback", "Retry"] + [action["name"] for action in action_list] if action_list else []

        is_valid = validate_behavior_tree(bt_xml, "xml", allowed_nodes=action_node)

        save = True
        if not is_valid[0]:
            print(f"Invalid Behavior Tree generated for query: {bt_xml}")
            print(f"Error: {is_valid[1]}")
            save = False
        else:
            bt_json = xml_to_json(bt_xml)

            is_valid = validate_behavior_tree(json.dumps(bt_json), "json", allowed_nodes=action_node)

            if not is_valid[0]:
                print(f"Invalid JSON conversion for query: {bt_json}")
                print(f"Invalid JSON conversion : {is_valid[1]}")
                save = False
            
            if save:
                print(f"Query {query} generated successfully")

                # Update the last queries
                last_queries.append(query)
                if len(last_queries) > 10:
                    last_queries.pop(0)  # Keep only the last 10 queries
                
                # Save the data entry
                dataset_entry = {
                    "object_context": reduced_object_list,
                    "actions_dictionary": action_list,
                    "query": query,
                    "explanation": explanation,
                    "bt_xml": bt_xml,
                    "bt_json": bt_json
                }
                dataset.append(dataset_entry)
            

    
    print(f"Dataset of {dataset_size} entries generated")
    return dataset

# Generate the dataset
dataset = generate_dataset(object_list, action_list, dataset_size=200)
# Out:
# Query Please locate the first aid kit and bring it to me. generated successfully
# Query Could you please locate the set of screwdrivers and bring it to me, then place it on the countertop? generated successfully
# Query Could you please navigate to the ladder, pick it up with medium grip strength, and then place it upright next to the stack of wood? generated successfully
# Query Could you please navigate to the wooden cutting board on the dining table, pick up the silver knife with medium grip strength, and then place the knife upright on the counter? generated successfully
# Query Please locate the crowbar, pick it up with high grip strength, and then navigate to the car jack to place the crowbar next to it. generated successfully
# Query Could you please navigate to the cooking pot, pick it up with medium grip strength, and then place it on the stove in an upright position? generated successfully
# Query Could you please locate the thermal blanket, pick it up with low grip strength, and then navigate to the tarp to place it underneath? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, and then navigate to the sleeping bag to place the fire extinguisher next to it? generated successfully
# Query Could you please locate the map, pick it up with medium grip strength, and then navigate to the cooking pot to place the map next to it? generated successfully
# Query Could you please locate the walkie-talkie and bring it to me, then navigate to the kitchen counter to place it upright? generated successfully
# Query Could you please locate the fireproof blanket, pick it up with medium grip strength, and then navigate to the living room to place it flat on the floor? generated successfully
# Invalid Behavior Tree generated for query: <root main_tree_to_execute="LocatePickPlaceBinocularsSequence">
#     <BehaviorTree ID="LocatePickPlaceBinocularsSequence">
#         <Sequence name="LocatePickPlaceBinoculars">
#             <Retry num_attempts="3">
#                 <Locate object="a pair of binoculars"
#                         position_x="{binoculars_position_x}"
#                         position_y="{binoculars_position_y}"
#                         position_z="{binoculars_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Pick object="a pair of binoculars"
#                       grip_strength="low"
#                       precision="medium" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Navigate x="12.0" y="4.0" />  <!-- Position of the map -->
#             </Retry>
#             <Retry num_attempts="2">
#                 <Place object="a pair of binoculars"
#                        surface="ground"  <!-- Assuming placing on ground next to the map -->
#                        orientation="upright"
#                        alignment="center" />
#             </Retry>
#         </Sequence>
#     </BehaviorTree>
# </root>
# Error: ['XML Parsing Error: not well-formed (invalid token): line 20, column 41']
# Query Could you please navigate to the empty glass cup next to the sink, pick it up with low grip strength, and then place it upright on the dining table? generated successfully
# Query Could you please locate the sleeping bag, pick it up with medium grip strength, then navigate to the fire extinguisher and place the sleeping bag next to it? generated successfully
# Query Could you please navigate to the pair of gloves, pick them up with low grip strength, and then locate the emergency whistle and bring both items to the tarp? generated successfully
# Invalid Behavior Tree generated for query:
# Error: ['XML Parsing Error: no element found: line 1, column 0']
# Query Could you please locate the safety helmet, pick it up with medium grip strength, and then navigate to the folding chair to place the helmet on it upright? generated successfully
# Query Could you please locate the water bottle, pick it up with medium grip strength, and then navigate to the thermal blanket to place the water bottle next to it? generated successfully
# Query Could you please locate the folding chair, pick it up with medium grip strength, and then navigate to the stack of wood to place the chair next to it? generated successfully
# Query Could you please locate the medical splint, pick it up with high grip strength, then navigate to the stack of wood and place the splint on top of it upright? generated successfully
# Query Could you please locate the backpack, pick it up with medium grip strength, and then navigate to the table to place the backpack upright? generated successfully
# Query Could you please locate the first aid kit, pick it up with high grip strength, then navigate to the thermal blanket and place the first aid kit on top of it upright? generated successfully
# Query Could you please navigate to the wooden cutting board on the dining table, pick it up with medium grip strength, then locate the red apple on the kitchen counter and place the cutting board flat next to it? generated successfully
# Query Could you please locate the crowbar, pick it up with high grip strength, and then navigate to the camping stove to place the crowbar next to it? generated successfully
# Query Could you please locate the car jack, pick it up with medium grip strength, then navigate to the first aid kit and place the car jack next to it upright? generated successfully
# Query Could you please locate the flashlight, pick it up with medium grip strength, then navigate to the wooden cutting board on the dining table and place the flashlight next to it upright? generated successfully
# Query Could you please locate the red apple on the kitchen counter, pick it up with low grip strength, and then navigate to the sleeping bag to place the apple on top of it upright? generated successfully
# Query Could you please locate the bag of rice, pick it up with medium grip strength, then navigate to the folding chair and place the bag of rice on it upright? generated successfully
# Query Could you please locate the ceramic plate with some bread crumbs, pick it up with medium grip strength, and then navigate to the sink to place the plate in the empty glass cup? generated successfully
# Query Could you please locate the pair of gloves, pick them up with medium grip strength, then navigate to the camping stove and place the gloves next to it upright? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, then navigate to the camping stove and use the extinguisher to put out any flames if there are any? generated successfully
# Query Could you please locate the safety helmet, pick it up with high grip strength, then navigate to the ladder and place the safety helmet on the top rung upright? generated successfully
# Query Could you please locate the cooking pot, pick it up with medium grip strength, then navigate to the water bottle and pour some water into the pot before placing it back on the counter upright? generated successfully
# Query Could you please locate the map, pick it up with low grip strength, then navigate to the folding chair and place the map on it upright? generated successfully
# Invalid Behavior Tree generated for query: <root main_tree_to_execute="ToolkitAndBootsRepairSequence">
#     <BehaviorTree ID="ToolkitAndBootsRepairSequence">
#         <Sequence name="ToolkitAndBootsRepair">
#             <Retry num_attempts="3">
#                 <Locate object="a toolkit"
#                         position_x="{toolkit_position_x}"
#                         position_y="{toolkit_position_y}"
#                         position_z="{toolkit_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Pick object="a toolkit"
#                       grip_strength="high"
#                       precision="medium" />
#             </Retry>
#             <Retry num_attempts="3">
#                 <Locate object="a pair of boots"
#                         position_x="{boots_position_x}"
#                         position_y="{boots_position_y}"
#                         position_z="{boots_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Navigate x="{boots_position_x}" y="{boots_position_y}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <UseToolsFromToolkit object="a pair of boots" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Place object="a pair of boots"
#                        surface="ground"
#                        orientation="upright"
#                        alignment="center" />
#             </Retry>
#         </Sequence>
#     </BehaviorTree>
# </root>
# Error: ['Invalid node <UseToolsFromToolkit> found.']
# Invalid Behavior Tree generated for query: <root main_tree_to_execute="LocateAndUseToolkitSequence">
#     <BehaviorTree ID="LocateAndUseToolkitSequence">
#         <Sequence name="LocateAndUseToolkit">
#             <Retry num_attempts="3">
#                 <Locate object="a toolkit"
#                         position_x="{toolkit_position_x}"
#                         position_y="{toolkit_position_y}"
#                         position_z="{toolkit_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Pick object="a toolkit"
#                       grip_strength="medium"
#                       precision="high" />
#             </Retry>
#             <Retry num_attempts="3">
#                 <Locate object="a stack of wood"
#                         position_x="{stack_of_wood_position_x}"
#                         position_y="{stack_of_wood_position_y}"
#                         position_z="{stack_of_wood_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Navigate x="{stack_of_wood_position_x}" y="{stack_of_wood_position_y}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Pick object="a hammer"
#                       grip_strength="medium"
#                       precision="high" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <UseTool object="hammer"
#                          target="stack of wood" />
#             </Retry>
#         </Sequence>
#     </BehaviorTree>
# </root>
# Error: ['Invalid node <UseTool> found.']
# Query Could you please locate the fireproof blanket, pick it up with medium grip strength, then navigate to the thermal blanket and place the fireproof blanket on top of it upright? generated successfully
# Invalid Behavior Tree generated for query:
# Error: ['XML Parsing Error: no element found: line 1, column 0']
# Query Could you please locate the medical splint, pick it up with medium grip strength, then navigate to the kitchen counter and place the splint next to the fire extinguisher upright? generated successfully
# Query Could you please locate the emergency whistle, pick it up with low grip strength, then navigate to the stack of wood and place the whistle on top of the wood upright? generated successfully
# Invalid Behavior Tree generated for query: <root main_tree_to_execute="LocatePickNavigateDigSequence">
#     <BehaviorTree ID="LocatePickNavigateDigSequence">
#         <Sequence name="LocatePickNavigateDig">
#             <Retry num_attempts="3">
#                 <Locate object="shovel"
#                         position_x="{shovel_position_x}"
#                         position_y="{shovel_position_y}"
#                         position_z="{shovel_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Pick object="shovel"
#                       grip_strength="high"
#                       precision="medium" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Navigate x="18.1" y="7.9" />
#             </Retry>
#             <Retry num_attempts="1">
#                 <Action name="Dig" description="Use the shovel to dig a small hole" />
#             </Retry>
#         </Sequence>
#     </BehaviorTree>
# </root>
# Error: ['Invalid node <Action> found.', "<Action> node is missing 'ID' attribute."]
# Query Could you please locate the red apple on the kitchen counter, pick it up with medium grip strength, then navigate to the dining table and place the apple in the center upright? generated successfully
# Query Could you please locate the thermal blanket, pick it up with medium grip strength, then navigate to the tarp and place the thermal blanket underneath it upright? generated successfully
# Invalid Behavior Tree generated for query:
# Error: ['XML Parsing Error: no element found: line 1, column 0']
# Query Could you please locate the folding chair, pick it up with medium grip strength, then navigate to the ladder and place the folding chair at the base of the ladder upright? generated successfully
# Query Could you please locate the pair of gloves, pick them up with low grip strength, then navigate to the car jack and place the gloves next to it upright? generated successfully
# Query Could you please locate the silver knife, pick it up with medium grip strength, then navigate to the ceramic plate and place the knife next to it upright? generated successfully
# Query Could you please locate the flashlight, pick it up with medium grip strength, then navigate to the backpack and place the flashlight inside it upright? generated successfully
# Query Could you please locate the crowbar, pick it up with high grip strength, then navigate to the empty glass cup next to the sink and place the crowbar inside the cup upright? generated successfully
# Query Could you please locate the water filter, pick it up with medium grip strength, then navigate to the bag of rice and place the water filter next to it upright? generated successfully
# Query Could you please locate the first aid kit, pick it up with high grip strength, then navigate to the emergency whistle and place the first aid kit next to it upright? generated successfully
# Query Could you please locate the bag of rice, pick it up with medium grip strength, then navigate to the kitchen counter and place the bag of rice next to the red apple upright? generated successfully
# Query Could you please locate the cooking pot, pick it up with medium grip strength, navigate to the wooden cutting board on the dining table, and place the cooking pot on the board upright? generated successfully
# Query Could you please locate the roll of duct tape, pick it up with medium grip strength, then navigate to the medical splint and place the duct tape next to it upright? generated successfully
# Query Could you please locate the can of soup, pick it up with medium grip strength, then navigate to the kitchen counter and place the can of soup next to the red apple upright? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, then navigate to the stack of wood and place the fire extinguisher next to it upright? generated successfully
# Query Could you please locate the thermal blanket, pick it up with low grip strength, then navigate to the first aid kit and place the thermal blanket next to it upright? generated successfully
# Query Could you please locate the bag of sand, pick it up with medium grip strength, then navigate to the folding chair and place the bag of sand on the seat of the chair upright? generated successfully
# Query Could you please locate the hammer, pick it up with high grip strength, then navigate to the folding chair and place the hammer on the seat of the chair upright? generated successfully
# Query Could you please locate the thermal blanket, pick it up with low grip strength, navigate to the stack of wood, and place the thermal blanket on top of the stack upright? generated successfully
# Query Could you please locate the pair of gloves, pick them up with low grip strength, then navigate to the wooden cutting board on the dining table and place the gloves on the board upright? generated successfully
# Query Could you please locate the sleeping bag, pick it up with medium grip strength, then navigate to the medical splint and place the sleeping bag next to it upright? generated successfully
# Query Could you please locate the medical splint, pick it up with medium grip strength, then navigate to the pair of boots and place the medical splint next to the boots upright? generated successfully
# Query Could you please locate the camping stove, pick it up with medium grip strength, then navigate to the wooden cutting board on the dining table and place the camping stove on the board upright? generated successfully
# Query Could you please locate the water filter, pick it up with medium grip strength, then navigate to the kitchen counter and place the water filter next to the red apple upright? generated successfully
# Query Could you please locate the backpack, pick it up with medium grip strength, then navigate to the first aid kit and place the backpack next to it upright? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, then navigate to the can of soup and place the fire extinguisher next to it upright? generated successfully
# Query Could you please locate the box of matches, pick it up with low grip strength, then navigate to the wooden cutting board on the dining table and place the box of matches on the board upright? generated successfully
# Query Could you please locate the map, pick it up with medium grip strength, then navigate to the thermal blanket and place the map on top of the blanket upright? generated successfully
# Query Could you please locate the camping stove, pick it up with high grip strength, navigate to the tarp, and place the camping stove on top of the tarp upright? generated successfully
# Invalid Behavior Tree generated for query: <root main_tree_to_execute="LocatePickPlaceWhistleSequence">
#     <BehaviorTree ID="LocatePickPlaceWhistleSequence">
#         <Sequence name="LocatePickPlaceWhistle">
#             <Retry num_attempts="3">
#                 <Locate object="an emergency whistle"
#                         position_x="{whistle_position_x}"
#                         position_y="{whistle_position_y}"
#                         position_z="{whistle_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Pick object="an emergency whistle"
#                       grip_strength="medium"
#                       precision="high" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Navigate x="18.1" y="7.9" />  <!-- Position of the camping stove -->
#             </Retry>
#             <Retry num_attempts="2">
#                 <Place object="an emergency whistle"
#                        surface="ground"  <!-- Assuming the ground is the only available surface next to the camping stove -->
#                        orientation="upright"
#                        alignment="center" />
#             </Retry>
#         </Sequence>
#     </BehaviorTree>
# </root>
# Error: ['XML Parsing Error: not well-formed (invalid token): line 20, column 41']
# Query Could you please locate the car jack, pick it up with high grip strength, then navigate to the bag of sand and place the car jack next to it upright? generated successfully
# Query Could you please locate the silver knife laying on the counter, pick it up with medium grip strength, then navigate to the cooking pot and place the knife inside the pot upright? generated successfully
# Query Could you please locate the bag of rice, pick it up with medium grip strength, then navigate to the counter and place the bag of rice next to the silver knife upright? generated successfully
# Query Could you please locate the safety helmet, pick it up with medium grip strength, then navigate to the sleeping bag and place the helmet on top of the sleeping bag upright? generated successfully
# Query Could you please locate the medical splint, pick it up with medium grip strength, navigate to the cooking pot, and place the medical splint inside the pot upright? generated successfully
# Query Could you please locate the walkie-talkie, pick it up with medium grip strength, then navigate to the fireproof blanket and place the walkie-talkie on top of it upright? generated successfully
# Query Could you please locate the red apple sitting on the kitchen counter, pick it up with medium grip strength, then navigate to the cooking pot and place the apple inside the pot upright? generated successfully
# Query Could you please locate the pair of gloves, pick them up with low grip strength, then navigate to the first aid kit and place the gloves inside the kit upright? generated successfully
# Query Could you please locate the ladder, pick it up with high grip strength, then navigate to the tarp and place the ladder on top of the tarp upright? generated successfully
# Query Could you please locate the cooking pot, pick it up with medium grip strength, navigate to the bag of rice, and place the cooking pot inside the bag of rice upright? generated successfully
# Query Could you please locate the first aid kit, pick it up with medium grip strength, navigate to the safety helmet, and place the first aid kit inside the helmet upright? generated successfully
# Query Could you please locate the flashlight, pick it up with medium grip strength, then navigate to the first aid kit and place the flashlight inside the kit upright? generated successfully
# Query Could you please locate the emergency whistle, pick it up with low grip strength, then navigate to the backpack and place the whistle inside the backpack upright? generated successfully
# Query Could you please locate the wooden cutting board on the dining table, pick it up with medium grip strength, navigate to the sleeping bag, and place the cutting board on top of the sleeping bag upright? generated successfully
# Query Could you please locate the fireproof blanket, pick it up with high grip strength, navigate to the wooden cutting board on the dining table, and place the fireproof blanket on top of the cutting board upright? generated successfully
# Query Could you please locate the medical splint, pick it up with medium grip strength, then navigate to the first aid kit and place the splint inside the kit upright? generated successfully
# Query Could you please locate the roll of duct tape, pick it up with medium grip strength, then navigate to the fire extinguisher and place the duct tape next to it aligned to the center? generated successfully
# Query Could you please locate the folding chair, pick it up with medium grip strength, then navigate to the stack of wood and place the chair next to it aligned to the center? generated successfully
# Query Could you please locate the silver knife laying on the counter, pick it up with high grip strength, then navigate to the backpack and place the knife inside the backpack upright? generated successfully
# Query Could you please locate the camping stove, pick it up with medium grip strength, navigate to the bag of sand, and place the camping stove on top of the bag of sand upright? generated successfully
# Query Could you please locate the cooking pot, pick it up with medium grip strength, navigate to the kitchen counter, and place the cooking pot on the counter upright? generated successfully
# Query Could you please locate the car jack, pick it up with high grip strength, then navigate to the tarp and place the car jack underneath the tarp aligned to the center? generated successfully
# Query Could you please locate the bag of rice, pick it up with medium grip strength, then navigate to the kitchen counter and place the bag of rice on the counter upright? generated successfully
# Query Could you please locate the compass, pick it up with low grip strength, navigate to the first aid kit, and place the compass inside the kit aligned to the center? generated successfully
# Query Could you please locate the walkie-talkie, pick it up with medium grip strength, then navigate to the folding chair and place the walkie-talkie on the seat of the chair upright? generated successfully
# Query Could you please locate the thermal blanket, pick it up with low grip strength, then navigate to the bag of sand and place the thermal blanket on top of the bag of sand aligned to the center? generated successfully
# Query Could you please locate the wooden cutting board on the dining table, pick it up with medium grip strength, then navigate to the toolkit and place the cutting board inside the toolkit aligned to the center? generated successfully
# Query Could you please locate the medical splint, pick it up with medium grip strength, navigate to the water bottle, and place the splint next to the water bottle aligned to the center? generated successfully
# Query Could you please locate the pair of binoculars, pick them up with medium grip strength, then navigate to the safety helmet and place the binoculars on top of the helmet aligned to the center? generated successfully
# Query Could you please locate the box of matches, pick it up with low grip strength, navigate to the camping stove, and place the box of matches next to the stove aligned to the center? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, then navigate to the thermal blanket and place the fire extinguisher next to the blanket aligned to the center? generated successfully
# Query Could you please locate the emergency whistle, pick it up with low grip strength, then navigate to the medical splint and place the whistle next to the splint aligned to the center? generated successfully
# Query Could you please locate the shovel, pick it up with medium grip strength, then navigate to the sleeping bag and place the shovel next to the sleeping bag aligned to the center? generated successfully
# Query Could you please locate the red apple sitting on the kitchen counter, pick it up with medium grip strength, navigate to the table, and place the apple on the table upright aligned to the center? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, navigate to the camping stove, and place the fire extinguisher next to the stove aligned to the center? generated successfully
# Query Could you please locate the empty glass cup next to the sink, pick it up with low grip strength, then navigate to the wooden cutting board on the dining table and place the glass cup on the cutting board aligned to the center? generated successfully
# Query Could you please locate the roll of duct tape, pick it up with medium grip strength, navigate to the folding chair, and wrap the duct tape around one of the chair legs for added stability? generated successfully
# Query Could you please locate the camping stove, pick it up with medium grip strength, then navigate to the fireproof blanket and place the stove on top of the blanket aligned to the center? generated successfully
# Query Could you please locate the ladder, pick it up with high grip strength, then navigate to the stack of wood and place the ladder next to the stack aligned to the center? generated successfully
# Query Could you please locate the first aid kit, pick it up with medium grip strength, navigate to the sleeping bag, and place the first aid kit next to the sleeping bag aligned to the center? generated successfully
# Query Could you please locate the camping stove, pick it up with medium grip strength, navigate to the sleeping bag, and place the camping stove next to the sleeping bag aligned to the center? generated successfully
# Query Could you please locate the toolkit, pick it up with high grip strength, then navigate to the folding chair and place the toolkit on the chair aligned to the center? generated successfully
# Query Could you please locate the bag of rice, pick it up with medium grip strength, navigate to the kitchen counter, and place the bag of rice on the counter aligned to the center? generated successfully
# Query Could you please locate the flashlight, pick it up with medium grip strength, navigate to the ladder, and place the flashlight on the top rung of the ladder aligned to the center? generated successfully
# Query Could you please locate the can of soup, pick it up with medium grip strength, then navigate to the kitchen counter and place the can of soup upright in the center of the counter? generated successfully
# Query Could you please locate the safety helmet, pick it up with high grip strength, then navigate to the camping stove and place the helmet on the stove aligned to the center? generated successfully
# Query Could you please locate the pair of boots, pick them up with medium grip strength, navigate to the thermal blanket, and place the boots on top of the blanket aligned to the center? generated successfully
# Query Could you please locate the medical splint, pick it up with medium grip strength, navigate to the thermal blanket, and place the splint on top of the blanket aligned to the center? generated successfully
# Query Could you please locate the silver knife laying on the counter, pick it up with low grip strength, then navigate to the backpack and place the knife inside the backpack aligned to the center? generated successfully
# Query Could you please locate the red apple sitting on the kitchen counter, pick it up with low grip strength, navigate to the stack of wood, and place the apple on top of the stack aligned to the center? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, navigate to the stack of wood, and place the fire extinguisher next to the stack aligned to the center? generated successfully
# Query Could you please locate the water bottle, pick it up with medium grip strength, then navigate to the stack of wood and place the water bottle next to the stack aligned to the center? generated successfully
# Query Could you please locate the car jack, pick it up with high grip strength, navigate to the camping stove, and place the car jack next to the stove aligned to the center? generated successfully
# Query Could you please locate the cooking pot, pick it up with medium grip strength, then navigate to the bag of rice and place the pot next to the bag of rice aligned to the center? generated successfully
# Invalid Behavior Tree generated for query:
# Error: ['XML Parsing Error: no element found: line 1, column 0']
# Query Could you please locate the toolkit, pick it up with medium grip strength, navigate to the stack of wood, and place the toolkit on top of the stack aligned to the center? generated successfully
# Invalid Behavior Tree generated for query:
# Error: ['XML Parsing Error: no element found: line 1, column 0']
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, then navigate to the tarp and place the fire extinguisher under the tarp aligned to the center? generated successfully
# Query Could you please locate the bag of sand, pick it up with high grip strength, navigate to the cooking pot, and pour the sand into the pot while keeping it upright? generated successfully
# Query Could you please locate the water filter, pick it up with medium grip strength, navigate to the fire extinguisher, and place the water filter next to the extinguisher aligned to the center? generated successfully
# Query Could you please locate the camping stove, pick it up with medium grip strength, navigate to the folding chair, and place the camping stove on top of the chair aligned to the center? generated successfully
# Query Could you please locate the first aid kit, pick it up with medium grip strength, navigate to the wooden cutting board on the dining table, and place the first aid kit on the board aligned to the center? generated successfully
# Query Could you please locate the pair of boots, pick them up with medium grip strength, navigate to the rope, and place the boots next to the rope aligned to the center? generated successfully
# Query Could you please locate the sleeping bag, pick it up with low grip strength, navigate to the backpack, and place the sleeping bag inside the backpack aligned to the center? generated successfully
# Query Could you please locate the empty glass cup next to the sink, pick it up with low grip strength, navigate to the cooking pot, and pour water from the cup into the pot while keeping the cup upright? generated successfully
# Query Could you please locate the map, pick it up with medium grip strength, navigate to the pair of boots, and then place the map next to the boots aligned to the center? generated successfully
# Query Could you please locate the medical splint, pick it up with low grip strength, navigate to the folding chair, and place the medical splint on the chair aligned to the center? generated successfully
# Query Could you please locate the ceramic plate with some bread crumbs, pick it up with low grip strength, navigate to the sleeping bag, and place the plate on top of the sleeping bag aligned to the center? generated successfully
# Query Could you please locate the can of soup, pick it up with medium grip strength, navigate to the wooden cutting board on the dining table, and place the can of soup on the board aligned to the center? generated successfully
# Query Could you please locate the fireproof blanket, pick it up with high grip strength, navigate to the safety helmet, and then place the blanket underneath the helmet aligned to the center? generated successfully
# Query Could you please locate the flashlight, pick it up with medium grip strength, navigate to the outdoor shed, and place the flashlight inside the shed aligned to the center? generated successfully
# Query Could you please locate the toolkit, pick it up with high grip strength, navigate to the ladder, and place the toolkit at the base of the ladder aligned to the center? generated successfully
# Invalid Behavior Tree generated for query: <root main_tree_to_execute="LocateAndUseHammerSequence">
#     <BehaviorTree ID="LocateAndUseHammerSequence">
#         <Sequence name="LocateAndUseHammer">
#             <Retry num_attempts="3">
#                 <Locate object="hammer"
#                         position_x="{hammer_position_x}"
#                         position_y="{hammer_position_y}"
#                         position_z="{hammer_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Pick object="hammer"
#                       grip_strength="medium"
#                       precision="high" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Navigate x="{stack_of_wood_position_x}" y="{stack_of_wood_position_y}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Place object="hammer"
#                        surface="stack of wood"
#                        orientation="upright"
#                        alignment="center" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <UseTool object="hammer"
#                          action="drive nail"
#                          target="stack of wood"
#                          orientation="upright" />
#             </Retry>
#         </Sequence>
#     </BehaviorTree>
# </root>
# Error: ['Invalid node <UseTool> found.']
# Query Could you please locate the thermal blanket, pick it up with medium grip strength, navigate to the car jack, and then place the thermal blanket on top of the car jack aligned to the center? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, navigate to the can of soup, and then place the fire extinguisher next to the can of soup aligned to the center? generated successfully
# Query Could you please locate the tarp, pick it up with medium grip strength, navigate to the thermal blanket, and then place the tarp on top of the thermal blanket aligned to the center? generated successfully
# Invalid Behavior Tree generated for query:
# Error: ['XML Parsing Error: no element found: line 1, column 0']
# Query Could you please locate the pair of sunglasses, pick them up with low grip strength, navigate to the fire extinguisher, and then place the sunglasses next to the fire extinguisher aligned to the center? generated successfully
# Query Could you please locate the cooking pot, pick it up with medium grip strength, navigate to the bag of rice, and then place the cooking pot on top of the bag of rice aligned to the center? generated successfully
# Query Could you please locate the backpack, pick it up with medium grip strength, navigate to the dining table, and then place the backpack on the table aligned to the center? generated successfully
# Query Could you please locate the smartphone, pick it up with low grip strength, navigate to the camping stove, and then place the smartphone on the stove aligned to the center? generated successfully
# Query Could you please locate the shovel, pick it up with medium grip strength, navigate to the thermal blanket, and then place the shovel on top of the thermal blanket aligned to the center? generated successfully
# Query Could you please locate the safety helmet, pick it up with medium grip strength, navigate to the sleeping bag, and then place the safety helmet inside the sleeping bag aligned to the center? generated successfully
# Query Could you please locate the water bottle, pick it up with medium grip strength, navigate to the fireproof blanket, and then place the water bottle on top of the fireproof blanket aligned to the center? generated successfully
# Query Could you please locate the first aid kit, pick it up with high grip strength, navigate to the kitchen counter, and then place the first aid kit next to the red apple aligned to the center? generated successfully
# Query Could you please locate the bag of sand, pick it up with high grip strength, navigate to the toolkit, and then place the bag of sand next to the toolkit aligned to the center? generated successfully
# Query Could you please locate the hammer, pick it up with high grip strength, navigate to the stack of wood, and then use the hammer to secure the wood pieces together? generated successfully
# Query Could you please locate the map, pick it up with low grip strength, navigate to the stack of wood, and then place the map on top of the stack of wood aligned to the center? generated successfully
# Query Could you please locate the can of soup, pick it up with medium grip strength, navigate to the camping stove, and then place the can of soup on the stove aligned to the center? generated successfully
# Query Could you please locate the pair of gloves, pick them up with medium grip strength, navigate to the walkie-talkie, and then place the gloves next to the walkie-talkie aligned to the center? generated successfully
# Query Could you please locate the cooking pot, pick it up with medium grip strength, navigate to the stack of wood, and then place the cooking pot on top of the stack of wood aligned to the center? generated successfully
# Query Could you please locate the ceramic plate with some bread crumbs, pick it up with low grip strength, navigate to the folding chair, and then place the ceramic plate on the folding chair aligned to the center? generated successfully
# Query Could you please locate the backpack, pick it up with medium grip strength, navigate to the tarp, and then place the backpack on top of the tarp aligned to the center? generated successfully
# Invalid Behavior Tree generated for query:
# Error: ['XML Parsing Error: no element found: line 1, column 0']
# Query Could you please locate the safety helmet, pick it up with high grip strength, navigate to the car jack, and then place the safety helmet next to the car jack aligned to the center? generated successfully
# Invalid Behavior Tree generated for query: <root main_tree_to_execute="KnifeAndRicePreparationSequence">
#     <BehaviorTree ID="KnifeAndRicePreparationSequence">
#         <Sequence name="KnifeAndRicePreparation">
#             <Retry num_attempts="3">
#                 <Locate object="a folding knife"
#                         position_x="{knife_position_x}"
#                         position_y="{knife_position_y}"
#                         position_z="{knife_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Pick object="a folding knife"
#                       grip_strength="medium"
#                       precision="high" />
#             </Retry>
#             <Retry num_attempts="3">
#                 <Locate object="a bag of rice"
#                         position_x="{rice_position_x}"
#                         position_y="{rice_position_y}"
#                         position_z="{rice_position_z}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Navigate x="{rice_position_x}" y="{rice_position_y}" />
#             </Retry>
#             <Retry num_attempts="2">
#                 <Action name="CutOpen"
#                         description="Cut open the bag of rice"
#                         params="{'object': 'a bag of rice', 'tool': 'a folding knife'}" />
#             </Retry>
#         </Sequence>
#     </BehaviorTree>
# </root>
# Error: ['Invalid node <Action> found.', "<Action> node is missing 'ID' attribute."]
# Query Could you please locate the fireproof blanket, pick it up with medium grip strength, navigate to the medical splint, and then place the fireproof blanket next to the medical splint aligned to the center? generated successfully
# Query Could you please locate the compass, pick it up with medium grip strength, navigate to the backpack, and then place the compass inside the backpack aligned to the center? generated successfully
# Query Could you please locate the thermal blanket, pick it up with medium grip strength, navigate to the sleeping bag, and then place the thermal blanket on top of the sleeping bag aligned to the center? generated successfully
# Query Could you please locate the water filter, pick it up with medium grip strength, navigate to the empty glass cup next to the sink, and then pour water from the water filter into the glass cup aligned to the center? generated successfully
# Query Could you please locate the red apple on the kitchen counter, pick it up with low grip strength, navigate to the wooden cutting board on the dining table, and then place the apple on the cutting board aligned to the center? generated successfully
# Query Could you please locate the ladder, pick it up with medium grip strength, navigate to the roof access point, and then place the ladder upright against the wall aligned to the center? generated successfully
# Query Could you please locate the bag of rice, pick it up with medium grip strength, navigate to the sleeping bag, and then place the bag of rice on top of the sleeping bag aligned to the center? generated successfully
# Query Could you please locate the notebook and pen, pick them up with medium grip strength, navigate to the backpack, and then place the notebook and pen inside the backpack aligned to the center? generated successfully
# Query Could you please locate the walkie-talkie, pick it up with medium grip strength, navigate to the ladder, and then place the walkie-talkie on the top rung of the ladder aligned to the center? generated successfully
# Query Could you please locate the camping stove, pick it up with medium grip strength, navigate to the stack of wood, and then place the camping stove on top of the stack of wood aligned to the center? generated successfully
# Query Could you please locate the toolkit, pick it up with medium grip strength, navigate to the folding chair, and then place the toolkit on the folding chair aligned to the center? generated successfully
# Query Could you please locate the fireproof blanket, pick it up with high grip strength, navigate to the living room, and then place the fireproof blanket on the couch aligned to the center? generated successfully
# Query Could you please locate the medical splint, pick it up with medium grip strength, navigate to the water bottle, and then place the medical splint next to the water bottle aligned to the center? generated successfully
# Query Could you please locate the pair of gloves, pick them up with low grip strength, navigate to the bag of sand, and then place the gloves on top of the bag of sand aligned to the center? generated successfully
# Query Could you please locate the cooking pot, pick it up with medium grip strength, navigate to the folding chair, and then place the cooking pot on the folding chair aligned to the center? generated successfully
# Query Could you please locate the flashlight, pick it up with medium grip strength, navigate to the first aid kit, and then place the flashlight next to the first aid kit aligned to the center? generated successfully
# Query Could you please locate the can of soup, pick it up with medium grip strength, navigate to the counter, and then place the can of soup next to the silver knife aligned to the center? generated successfully
# Query Could you please locate the emergency whistle, pick it up with medium grip strength, navigate to the kitchen counter, and then place the emergency whistle next to the red apple aligned to the center? generated successfully
# Query Could you please locate the car jack, pick it up with high grip strength, navigate to the stack of wood, and then place the car jack on top of the stack of wood aligned to the center? generated successfully
# Query Could you please locate the roll of duct tape, pick it up with medium grip strength, navigate to the backpack, and then place the duct tape inside the backpack aligned to the center? generated successfully
# Query Could you please locate the camping stove, pick it up with medium grip strength, navigate to the sleeping bag, and then place the camping stove next to the sleeping bag aligned to the center? generated successfully
# Invalid Behavior Tree generated for query:
# Error: ['XML Parsing Error: no element found: line 1, column 0']
# Query Could you please locate the safety helmet, pick it up with medium grip strength, navigate to the stack of wood, and then place the safety helmet on top of the stack of wood aligned to the center? generated successfully
# Query Could you please locate the fireproof blanket, pick it up with medium grip strength, navigate to the cooking pot, and then place the fireproof blanket underneath the cooking pot aligned to the center? generated successfully
# Query Could you please locate the camping stove, pick it up with high grip strength, navigate to the sleeping bag, and then place the camping stove on top of the sleeping bag aligned to the center? generated successfully
# Query Could you please locate the backpack, pick it up with medium grip strength, navigate to the wooden cutting board on the dining table, and then place the backpack on the wooden cutting board aligned to the center? generated successfully
# Query Could you please locate the bag of rice, pick it up with medium grip strength, navigate to the cooking pot, and then place the bag of rice inside the cooking pot aligned to the center? generated successfully
# Query Could you please locate the shovel, pick it up with high grip strength, navigate to the tarp, and then place the shovel on top of the tarp aligned to the center? generated successfully
# Query Could you please locate the folding knife, pick it up with medium grip strength, navigate to the kitchen counter, and then place the folding knife next to the red apple aligned to the center? generated successfully
# Query Could you please locate the silver knife laying on the counter, pick it up with medium grip strength, navigate to the ceramic plate with some bread crumbs, and then place the silver knife next to the ceramic plate aligned to the center? generated successfully
# Query Could you please locate the medical splint, pick it up with medium grip strength, navigate to the first aid kit, and then place the medical splint inside the first aid kit aligned to the center? generated successfully
# Query Could you please locate the fire extinguisher, pick it up with high grip strength, navigate to the stack of wood, and then place the fire extinguisher next to the stack of wood aligned to the center? generated successfully
# Query Could you please locate the car jack, pick it up with high grip strength, navigate to the car parked in the driveway, and then place the car jack underneath the car aligned to the center? generated successfully
# Dataset of 200 entries generated

# %%
dataset[4]["explanation"]
# Out:
# "Good, I will start by locating the crowbar using my sensors. Once I have its position, I will navigate to it and pick it up with high grip strength. After that, I will navigate to the car jack's location and place the crowbar next to it."

# %%
save_path="./queries_dataset2.json"
# Save the dataset to a JSON file
with open(save_path, "w") as file:
    json.dump(dataset, file, indent=4)
